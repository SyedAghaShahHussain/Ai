# %%
print("Hello world")
# Out:
# Hello world

# %%
x = input ("Enter your name")
print(x)
# Out:
# Enter your nameAgha Shah Hussain
# Agha Shah Hussain

# %%
# write a python program to print you best friend details
# Name , Age ,interest , Nationality
print ("My best friend name is Aamir ")
print ("he is 20 years old")
print("his interest is in gaming ")
# Out:
# My best friend name is Aamir
# he is 20 years old
# his interest is in gaming

# %%
name = input("Enter your name:")
age =input("Enter your age:")
interest = input("Enter younr Interest:")
nationality=input("Enter you nationality:")
# Out:
# Enter your name:Agha shah
# Enter your age:21
# Enter younr Interest:Sports
# Enter you nationality:Pakistan

# %%
num = int(input("Enter a number: "))

if (num % 2) == 0:
   print(f"{num} is Even")
else:
   print(f"{num} is Odd")
# Out:
# Enter a number: 5
# 5 is Odd

# %%
15/4
# Out:
# 3.75

# %%
15//4
# Out:
# 3

# %%
def greeting():
  print ("Assalam o Alikum")

# %%
greeting()
# Out:
# Assalam o Alikum

# %%
def odd_even(n):
  if n% 2 ==0:
    print("Given number is even ")
  else:
    print("Given number is odd")

# %%
a = input ("Enter a number")
print(odd_even(int(a)))
# odd_even (19)
# Out:
# Enter a number34
# Given number is even
# None

# %%
def frienddetail():

  name = input("Enter your friend name:")
  age =input("Enter your friends age:")
  interest = input("Enter your friends Interest:")
  nationality=input("Enter your friends nationality:")
  print(name, age, interest, nationality)

# %%
frienddetail()
# Out:
# Enter your friend name:aamir
# Enter your age:21
# Enter younr Interest:Sports
# Enter you nationality:Pakistan
# aamir 21 Sports Pakistan

# %%
for i in range(0,10):
  greeting()
# Out:
# Assalam o Alikum
# Assalam o Alikum
# Assalam o Alikum
# Assalam o Alikum
# Assalam o Alikum
# Assalam o Alikum
# Assalam o Alikum
# Assalam o Alikum
# Assalam o Alikum
# Assalam o Alikum

# %%
# print the table of given numbers

x = int (input ("Enter a number"))
for i  in range (1,11):
  print(i,"*",x,"=",i*x)
# Out:
# Enter a number3
# 1 * 3 = 3
# 2 * 3 = 6
# 3 * 3 = 9
# 4 * 3 = 12
# 5 * 3 = 15
# 6 * 3 = 18
# 7 * 3 = 21
# 8 * 3 = 24
# 9 * 3 = 27
# 10 * 3 = 30

# %%
def is_prime(n):
    if n == 0 or n == 1:
        return 0
    else:
        for i in range(2, n):
            if n % i == 0:
                return 0
    return 1

# %%
x = int (input("Enter a number"))
if is_prime(x)==0:
    print ("number is not prime")
else :
    print("number is prime")
# Out:
# Enter a number4
# not prime

# %%
count = 1
for i in range(400):
    if is_prime(i) == 1:
        print(count, "\t", i)
        if count >= 50:
            break
        count += 1
# Out:
# 1 	 2
# 2 	 3
# 3 	 5
# 4 	 7
# 5 	 11
# 6 	 13
# 7 	 17
# 8 	 19
# 9 	 23
# 10 	 29
# 11 	 31
# 12 	 37
# 13 	 41
# 14 	 43
# 15 	 47
# 16 	 53
# 17 	 59
# 18 	 61
# 19 	 67
# 20 	 71
# 21 	 73
# 22 	 79
# 23 	 83
# 24 	 89
# 25 	 97
# 26 	 101
# 27 	 103
# 28 	 107
# 29 	 109
# 30 	 113
# 31 	 127
# 32 	 131
# 33 	 137
# 34 	 139
# 35 	 149
# 36 	 151
# 37 	 157
# 38 	 163
# 39 	 167
# 40 	 173
# 41 	 179
# 42 	 181
# 43 	 191
# 44 	 193
# 45 	 197
# 46 	 199
# 47 	 211
# 48 	 223
# 49 	 227
# 50 	 229

# %%
square = lambda x:x*x*x

# %%
for i in range (10):
  print (square(i))
# Out:
# 0
# 1
# 8
# 27
# 64
# 125
# 216
# 343
# 512
# 729
